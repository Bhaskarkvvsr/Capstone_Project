# %% [markdown]
# ## Revolut FinCrime Challenge: Model Building
#
# There will be a notebook for each one of the Machine Learning Pipeline steps:
#
# 1. Data Analysis
# 2. Feature Engineering
# 3. Feature Selection
# 4. Model Building
#
# **This is the notebook for step 4: Model Building**
#
#
# ## Predicting Fradulent transactions
#
# The aim of the project is to build a machine learning model to find the fraudsters and take appropriate actions.
#
# ![SegmentLocal](fraud.gif "segment")
#
# ### Why is this important?
#
# Fraudsters can use our App to steal the data from other people's money from the outside into an account via TOP-UP's. So finding them and blocking them is very necessary.

# %% [markdown]
# ## Machine Learning Model build
#
# In the following cells, I will finally build the machine learning model, utilising the engineered data and the pre-selected features.
#
#
# Let's go ahead and load the dataset.

# %%
# to handle datasets
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 80
import seaborn as sns
# %matplotlib inline

# to build the models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# to persist the model
from sklearn.externals import joblib

# to evaluate the models
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.metrics import precision_recall_curve
from math import sqrt

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %%
# load dataset
# We load the datasets with the engineered values: we built and saved this datasets in the previous notebook.

train = pd.read_csv('../data/xtrain.csv')
test = pd.read_csv('../data/xtest.csv')

train.head()
# Out:
#                                 user_id                        transaction_id  \
# 0  00001f33-1d47-47a3-8955-e719172e788b  46285eca-e1b1-43a2-b8b0-c173b48f5a95
# 1  00001f33-1d47-47a3-8955-e719172e788b  1be7d138-fbaf-4216-8dc8-5056ec5f972c
# 2  00001f33-1d47-47a3-8955-e719172e788b  a9aa681d-451e-44c5-8df0-687661ac583d
# 3  00001f33-1d47-47a3-8955-e719172e788b  e6021128-f4c1-4164-b3de-697e66ad613c
# 4  00001f33-1d47-47a3-8955-e719172e788b  9499c9c9-c9a9-410f-820d-c6e92fed27fb
#
#             transaction_ts            registered_ts               birth_date  \
# 0  2019-04-21 11:04:53.081  2019-04-11 20:49:42.623  1994-08-17 00:00:00.000
# 1  2019-04-21 10:14:53.814  2019-04-11 20:49:42.623  1994-08-17 00:00:00.000
# 2  2019-04-19 21:05:53.192  2019-04-11 20:49:42.623  1994-08-17 00:00:00.000
# 3  2019-04-11 20:55:20.996  2019-04-11 20:49:42.623  1994-08-17 00:00:00.000
# 4  2019-04-11 20:53:54.700  2019-04-11 20:49:42.623  1994-08-17 00:00:00.000
#
#   transaction_date  user_age  is_fraud  avg_transaction_count  amount_gbp  \
# 0       2019-04-21        25         0              -0.508167    0.054028
# 1       2019-04-21        25         0              -0.508167    0.043652
# 2       2019-04-19        25         0              -0.508167    0.346044
# 3       2019-04-11        25         0              -0.508167   -0.121944
# 4       2019-04-11        25         0              -0.508167   -0.144518
#
#    transaction_hr  hr_gt_nine  state_COMPLETED  state_DECLINED  state_FAILED  \
# 0       -0.580791    0.504333         0.727990       -0.250637     -0.331993
# 1       -0.778896    0.504333         0.727990       -0.250637     -0.331993
# 2        1.400259    0.504333         0.727990       -0.250637     -0.331993
# 3        1.202154    0.504333         0.727990       -0.250637     -0.331993
# 4        1.202154    0.504333        -1.373644       -0.250637     -0.331993
#
#    state_REVERTED  currency_BGN  currency_CHF  currency_CZK  currency_EUR  \
# 0       -0.481188     -0.112081     -0.174942     -0.138751      1.256661
# 1       -0.481188     -0.112081     -0.174942     -0.138751      1.256661
# 2       -0.481188     -0.112081     -0.174942     -0.138751      1.256661
# 3       -0.481188     -0.112081     -0.174942     -0.138751      1.256661
# 4        2.078191     -0.112081     -0.174942     -0.138751      1.256661
#
#    currency_GBP  currency_HRK  currency_HUF  currency_PLN  currency_RON  \
# 0     -0.527487      -0.13125     -0.176167     -0.322369     -0.265881
# 1     -0.527487      -0.13125     -0.176167     -0.322369     -0.265881
# 2     -0.527487      -0.13125     -0.176167     -0.322369     -0.265881
# 3     -0.527487      -0.13125     -0.176167     -0.322369     -0.265881
# 4     -0.527487      -0.13125     -0.176167     -0.322369     -0.265881
#
#    currency_Rare  currency_SEK  currency_USD  country_BG  country_CH  \
# 0      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
# 1      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
# 2      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
# 3      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
# 4      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
#
#    country_CZ  country_DE  country_ES  country_FR  country_GB  country_HR  \
# 0   -0.151228   -0.121195   -0.233889   -0.316005   -0.616132   -0.107685
# 1   -0.151228   -0.121195   -0.233889   -0.316005   -0.616132   -0.107685
# 2   -0.151228   -0.121195   -0.233889   -0.316005   -0.616132   -0.107685
# 3   -0.151228   -0.121195   -0.233889   -0.316005   -0.616132   -0.107685
# 4   -0.151228   -0.121195   -0.233889   -0.316005   -0.616132   -0.107685
#
#    country_HU  country_IE  country_IT  country_LT  country_LV  country_PL  \
# 0   -0.176442    3.487115   -0.133202   -0.122211   -0.115657   -0.386638
# 1   -0.176442    3.487115   -0.133202   -0.122211   -0.115657   -0.386638
# 2   -0.176442    3.487115   -0.133202   -0.122211   -0.115657   -0.386638
# 3   -0.176442    3.487115   -0.133202   -0.122211   -0.115657   -0.386638
# 4   -0.176442    3.487115   -0.133202   -0.122211   -0.115657   -0.386638
#
#    country_PT  country_RO  country_Rare  country_SE  type_ATM  \
# 0   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
# 1   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
# 2   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
# 3   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
# 4   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
#
#    type_CARD_PAYMENT  type_EXCHANGE  type_FEE  type_TOPUP  type_TRANSFER  \
# 0           1.620741      -0.226587 -0.251627   -1.136748      -0.187375
# 1           1.620741      -0.226587 -0.251627   -1.136748      -0.187375
# 2          -0.617002      -0.226587 -0.251627    0.879702      -0.187375
# 3          -0.617002      -0.226587  3.974133   -1.136748      -0.187375
# 4          -0.617002      -0.226587 -0.251627    0.879702      -0.187375
#
#    age_18-27  age_28-37  age_38-47  age_48-57  age_58-67  age_Rare
# 0   1.369826  -0.639475  -0.482075   -0.34718  -0.200255 -0.167873
# 1   1.369826  -0.639475  -0.482075   -0.34718  -0.200255 -0.167873
# 2   1.369826  -0.639475  -0.482075   -0.34718  -0.200255 -0.167873
# 3   1.369826  -0.639475  -0.482075   -0.34718  -0.200255 -0.167873
# 4   1.369826  -0.639475  -0.482075   -0.34718  -0.200255 -0.167873

# %%
test.query('is_fraud == 1')
# Out:
#                                      user_id  \
# 1711    0211c232-1cc5-4591-9d1e-e132dd89ce92
# 1712    0211c232-1cc5-4591-9d1e-e132dd89ce92
# 1713    0211c232-1cc5-4591-9d1e-e132dd89ce92
# 1714    0211c232-1cc5-4591-9d1e-e132dd89ce92
# 1715    0211c232-1cc5-4591-9d1e-e132dd89ce92
# ...                                      ...
# 213262  ff5cd1d3-37ec-4605-a43e-9ff6359fb61e
# 213263  ff5cd1d3-37ec-4605-a43e-9ff6359fb61e
# 213264  ff5cd1d3-37ec-4605-a43e-9ff6359fb61e
# 213265  ff5cd1d3-37ec-4605-a43e-9ff6359fb61e
# 213266  ff5cd1d3-37ec-4605-a43e-9ff6359fb61e
#
#                               transaction_id           transaction_ts  \
# 1711    abcd6a12-3465-4ac6-9d84-f4df4e52bada  2019-04-06 12:25:43.288
# 1712    961a3a74-3c05-4353-83f4-042886ba9eb7  2019-04-06 21:56:54.959
# 1713    d43859ab-c81d-46ce-802b-2588ac32ea84  2019-04-06 12:34:02.339
# 1714    279af71c-c3bb-4ad2-ac90-214c27de1871  2019-04-06 22:01:38.707
# 1715    bdee2b4d-ff84-46b1-85cd-e49d84d85661  2019-04-06 12:26:02.314
# ...                                      ...                      ...
# 213262  d5277039-837f-4df3-bd60-e2484eb1a5ff  2019-05-01 17:56:57.452
# 213263  be449671-3e89-4dd9-9fee-8932e8912898  2019-05-01 16:40:01.608
# 213264  15043246-49a7-473d-a544-2180796e1213  2019-04-17 18:54:45.895
# 213265  326efd36-be81-4609-87aa-f2386c6c4765  2019-04-17 18:57:43.876
# 213266  8e15a4a5-3c21-471c-ad78-b147011eaee1  2019-04-30 22:07:41.832
#
#                   registered_ts               birth_date transaction_date  \
# 1711    2019-04-06 12:22:34.392  1979-10-14 00:00:00.000       2019-04-06
# 1712    2019-04-06 12:22:34.392  1979-10-14 00:00:00.000       2019-04-06
# 1713    2019-04-06 12:22:34.392  1979-10-14 00:00:00.000       2019-04-06
# 1714    2019-04-06 12:22:34.392  1979-10-14 00:00:00.000       2019-04-06
# 1715    2019-04-06 12:22:34.392  1979-10-14 00:00:00.000       2019-04-06
# ...                         ...                      ...              ...
# 213262  2019-04-17 15:05:01.597  1989-07-08 00:00:00.000       2019-05-01
# 213263  2019-04-17 15:05:01.597  1989-07-08 00:00:00.000       2019-05-01
# 213264  2019-04-17 15:05:01.597  1989-07-08 00:00:00.000       2019-04-17
# 213265  2019-04-17 15:05:01.597  1989-07-08 00:00:00.000       2019-04-17
# 213266  2019-04-17 15:05:01.597  1989-07-08 00:00:00.000       2019-04-30
#
#         user_age  is_fraud  avg_transaction_count  amount_gbp  transaction_hr  \
# 1711          40         1               2.249513   -0.144518       -0.382686
# 1712          40         1               2.249513    0.278958        1.400259
# 1713          40         1               2.249513    0.278958       -0.382686
# 1714          40         1               2.249513    0.283194        1.598364
# 1715          40         1               2.249513    0.278958       -0.382686
# ...          ...       ...                    ...         ...             ...
# 213262        30         1               0.594905   -0.108095        0.607839
# 213263        30         1               0.594905    1.314037        0.409734
# 213264        30         1               0.594905   -0.090434        0.805944
# 213265        30         1               0.594905   -0.122961        0.805944
# 213266        30         1               0.594905   -0.144518        1.598364
#
#         hr_gt_nine  state_COMPLETED  state_DECLINED  state_FAILED  \
# 1711      0.504333        -1.373644       -0.250637     -0.331993
# 1712      0.504333         0.727990       -0.250637     -0.331993
# 1713      0.504333         0.727990       -0.250637     -0.331993
# 1714      0.504333         0.727990       -0.250637     -0.331993
# 1715      0.504333         0.727990       -0.250637     -0.331993
# ...            ...              ...             ...           ...
# 213262    0.504333        -1.373644        3.989834     -0.331993
# 213263    0.504333         0.727990       -0.250637     -0.331993
# 213264    0.504333         0.727990       -0.250637     -0.331993
# 213265    0.504333         0.727990       -0.250637     -0.331993
# 213266    0.504333        -1.373644       -0.250637      3.012115
#
#         state_REVERTED  currency_BGN  currency_CHF  currency_CZK  \
# 1711          2.078191     -0.112081     -0.174942     -0.138751
# 1712         -0.481188     -0.112081     -0.174942     -0.138751
# 1713         -0.481188     -0.112081     -0.174942     -0.138751
# 1714         -0.481188     -0.112081     -0.174942     -0.138751
# 1715         -0.481188     -0.112081     -0.174942     -0.138751
# ...                ...           ...           ...           ...
# 213262       -0.481188     -0.112081     -0.174942     -0.138751
# 213263       -0.481188     -0.112081     -0.174942     -0.138751
# 213264       -0.481188     -0.112081     -0.174942     -0.138751
# 213265       -0.481188     -0.112081     -0.174942     -0.138751
# 213266       -0.481188     -0.112081     -0.174942     -0.138751
#
#         currency_EUR  currency_GBP  currency_HRK  currency_HUF  currency_PLN  \
# 1711       -0.795759      1.895780      -0.13125     -0.176167     -0.322369
# 1712       -0.795759      1.895780      -0.13125     -0.176167     -0.322369
# 1713       -0.795759      1.895780      -0.13125     -0.176167     -0.322369
# 1714       -0.795759      1.895780      -0.13125     -0.176167     -0.322369
# 1715       -0.795759      1.895780      -0.13125     -0.176167     -0.322369
# ...              ...           ...           ...           ...           ...
# 213262      1.256661     -0.527487      -0.13125     -0.176167     -0.322369
# 213263      1.256661     -0.527487      -0.13125     -0.176167     -0.322369
# 213264      1.256661     -0.527487      -0.13125     -0.176167     -0.322369
# 213265      1.256661     -0.527487      -0.13125     -0.176167     -0.322369
# 213266      1.256661     -0.527487      -0.13125     -0.176167     -0.322369
#
#         currency_RON  currency_Rare  currency_SEK  currency_USD  country_BG  \
# 1711       -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 1712       -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 1713       -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 1714       -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 1715       -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# ...              ...            ...           ...           ...         ...
# 213262     -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 213263     -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 213264     -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 213265     -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
# 213266     -0.265881      -0.197194       -0.1061     -0.290565   -0.116779
#
#         country_CH  country_CZ  country_DE  country_ES  country_FR  \
# 1711     -0.199412   -0.151228   -0.121195   -0.233889   -0.316005
# 1712     -0.199412   -0.151228   -0.121195   -0.233889   -0.316005
# 1713     -0.199412   -0.151228   -0.121195   -0.233889   -0.316005
# 1714     -0.199412   -0.151228   -0.121195   -0.233889   -0.316005
# 1715     -0.199412   -0.151228   -0.121195   -0.233889   -0.316005
# ...            ...         ...         ...         ...         ...
# 213262   -0.199412   -0.151228   -0.121195   -0.233889    3.164509
# 213263   -0.199412   -0.151228   -0.121195   -0.233889    3.164509
# 213264   -0.199412   -0.151228   -0.121195   -0.233889    3.164509
# 213265   -0.199412   -0.151228   -0.121195   -0.233889    3.164509
# 213266   -0.199412   -0.151228   -0.121195   -0.233889    3.164509
#
#         country_GB  country_HR  country_HU  country_IE  country_IT  \
# 1711      1.623028   -0.107685   -0.176442    -0.28677   -0.133202
# 1712      1.623028   -0.107685   -0.176442    -0.28677   -0.133202
# 1713      1.623028   -0.107685   -0.176442    -0.28677   -0.133202
# 1714      1.623028   -0.107685   -0.176442    -0.28677   -0.133202
# 1715      1.623028   -0.107685   -0.176442    -0.28677   -0.133202
# ...            ...         ...         ...         ...         ...
# 213262   -0.616132   -0.107685   -0.176442    -0.28677   -0.133202
# 213263   -0.616132   -0.107685   -0.176442    -0.28677   -0.133202
# 213264   -0.616132   -0.107685   -0.176442    -0.28677   -0.133202
# 213265   -0.616132   -0.107685   -0.176442    -0.28677   -0.133202
# 213266   -0.616132   -0.107685   -0.176442    -0.28677   -0.133202
#
#         country_LT  country_LV  country_PL  country_PT  country_RO  \
# 1711     -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 1712     -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 1713     -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 1714     -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 1715     -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# ...            ...         ...         ...         ...         ...
# 213262   -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 213263   -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 213264   -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 213265   -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
# 213266   -0.122211   -0.115657   -0.386638   -0.211368   -0.290697
#
#         country_Rare  country_SE  type_ATM  type_CARD_PAYMENT  type_EXCHANGE  \
# 1711       -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# 1712       -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# 1713       -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# 1714       -0.272798    -0.10378  7.336815          -0.617002      -0.226587
# 1715       -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# ...              ...         ...       ...                ...            ...
# 213262     -0.272798    -0.10378 -0.136299           1.620741      -0.226587
# 213263     -0.272798    -0.10378  7.336815          -0.617002      -0.226587
# 213264     -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# 213265     -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
# 213266     -0.272798    -0.10378 -0.136299          -0.617002      -0.226587
#
#         type_FEE  type_TOPUP  type_TRANSFER  age_18-27  age_28-37  age_38-47  \
# 1711   -0.251627    0.879702      -0.187375   -0.73002  -0.639475   2.074367
# 1712   -0.251627    0.879702      -0.187375   -0.73002  -0.639475   2.074367
# 1713   -0.251627    0.879702      -0.187375   -0.73002  -0.639475   2.074367
# 1714   -0.251627   -1.136748      -0.187375   -0.73002  -0.639475   2.074367
# 1715   -0.251627    0.879702      -0.187375   -0.73002  -0.639475   2.074367
# ...          ...         ...            ...        ...        ...        ...
# 213262 -0.251627   -1.136748      -0.187375   -0.73002   1.563783  -0.482075
# 213263 -0.251627   -1.136748      -0.187375   -0.73002   1.563783  -0.482075
# 213264 -0.251627    0.879702      -0.187375   -0.73002   1.563783  -0.482075
# 213265  3.974133   -1.136748      -0.187375   -0.73002   1.563783  -0.482075
# 213266 -0.251627    0.879702      -0.187375   -0.73002   1.563783  -0.482075
#
#         age_48-57  age_58-67  age_Rare  pred
# 1711     -0.34718  -0.200255 -0.167873     0
# 1712     -0.34718  -0.200255 -0.167873     0
# 1713     -0.34718  -0.200255 -0.167873     0
# 1714     -0.34718  -0.200255 -0.167873     0
# 1715     -0.34718  -0.200255 -0.167873     0
# ...           ...        ...       ...   ...
# 213262   -0.34718  -0.200255 -0.167873     0
# 213263   -0.34718  -0.200255 -0.167873     0
# 213264   -0.34718  -0.200255 -0.167873     0
# 213265   -0.34718  -0.200255 -0.167873     0
# 213266   -0.34718  -0.200255 -0.167873     0
#
# [1561 rows x 59 columns]

# %%
single_test_input = test[0:1]

# %%
test.query('transaction_id == "8b46f81c-a602-4d25-b81b-9d3b959f26ae"')
# Out:
#                                 user_id                        transaction_id  \
# 0  0001bd0a-3654-4e19-9d63-2df27e11ebd3  8b46f81c-a602-4d25-b81b-9d3b959f26ae
#
#             transaction_ts            registered_ts               birth_date  \
# 0  2019-04-05 18:27:43.950  2019-04-05 08:01:32.725  1956-05-25 00:00:00.000
#
#   transaction_date  user_age  is_fraud  avg_transaction_count  amount_gbp  \
# 0       2019-04-05        63         0               0.594905   -0.114956
#
#    transaction_hr  hr_gt_nine  state_COMPLETED  state_DECLINED  state_FAILED  \
# 0        0.805944    0.504333          0.72799       -0.250637     -0.331993
#
#    state_REVERTED  currency_BGN  currency_CHF  currency_CZK  currency_EUR  \
# 0       -0.481188     -0.112081     -0.174942     -0.138751     -0.795759
#
#    currency_GBP  currency_HRK  currency_HUF  currency_PLN  currency_RON  \
# 0       1.89578      -0.13125     -0.176167     -0.322369     -0.265881
#
#    currency_Rare  currency_SEK  currency_USD  country_BG  country_CH  \
# 0      -0.197194       -0.1061     -0.290565   -0.116779   -0.199412
#
#    country_CZ  country_DE  country_ES  country_FR  country_GB  country_HR  \
# 0   -0.151228   -0.121195   -0.233889   -0.316005    1.623028   -0.107685
#
#    country_HU  country_IE  country_IT  country_LT  country_LV  country_PL  \
# 0   -0.176442    -0.28677   -0.133202   -0.122211   -0.115657   -0.386638
#
#    country_PT  country_RO  country_Rare  country_SE  type_ATM  \
# 0   -0.211368   -0.290697     -0.272798    -0.10378 -0.136299
#
#    type_CARD_PAYMENT  type_EXCHANGE  type_FEE  type_TOPUP  type_TRANSFER  \
# 0          -0.617002      -0.226587  3.974133   -1.136748      -0.187375
#
#    age_18-27  age_28-37  age_38-47  age_48-57  age_58-67  age_Rare  pred
# 0   -0.73002  -0.639475  -0.482075   -0.34718   4.993639 -0.167873     0

# %%
r[0]
# Out:
# '8b46f81c-a602-4d25-b81b-9d3b959f26ae'

# %%
# capture the target
y_train = train['is_fraud']
y_test = test['is_fraud']

# %%
# load selected features
# we selected the features in the previous notebook

features = pd.read_csv('../data/selected_features.csv', header=None)
features = [x for x in features[0]]

# %%
features
# Out:
# ['avg_transaction_count',
#  'amount_gbp',
#  'transaction_hr',
#  'hr_gt_nine',
#  'state_DECLINED',
#  'state_FAILED',
#  'state_REVERTED',
#  'currency_BGN',
#  'currency_CHF',
#  'currency_CZK',
#  'currency_EUR',
#  'currency_GBP',
#  'currency_HRK',
#  'currency_PLN',
#  'currency_RON',
#  'currency_Rare',
#  'currency_SEK',
#  'currency_USD',
#  'country_BG',
#  'country_CH',
#  'country_CZ',
#  'country_DE',
#  'country_ES',
#  'country_FR',
#  'country_GB',
#  'country_HR',
#  'country_HU',
#  'country_IT',
#  'country_LT',
#  'country_LV',
#  'country_PL',
#  'country_PT',
#  'country_RO',
#  'country_Rare',
#  'country_SE',
#  'type_ATM',
#  'type_CARD_PAYMENT',
#  'type_EXCHANGE',
#  'type_FEE',
#  'type_TOPUP',
#  'type_TRANSFER',
#  'age_18-27',
#  'age_38-47',
#  'age_48-57',
#  'age_58-67',
#  'age_Rare']

# %%
# reduce the train and test set to the desired features

X_train = train[features]
X_test = test[features]

# %%
# lets check the target class distribution

y_train.value_counts()/len(y_train) * 100
# Out:
# 0    99.220387
# 1     0.779613
# Name: is_fraud, dtype: float64

# %% [markdown]
# From the above transactions we can observe that the dataset is clearly imbalanced, as there are only 0.77% fradulent transactions. If we directly build the model on this data model can be biased towards the majority class. So,we need to handle this data properly.

# %% [markdown]
# ### Handling the imbalanced Data
#
# There are various ways to handle the imbalanced datasets.
#
# 1. Generate synthetic samples(Oversampling, SMOTE etc.)
# 2. Trying penalized models
# 3. Trying a different perspective(By looking at this problem as anomaly detection use case)
# 4. Assigning higher weights to minority class(using class_weight parameter)
#
# For this problem I have choosed the last way to handle the imbalance data i.e by using class_weight parameter. However, for better results we have to try out various approaches to figure out the best.

# %% [markdown]
# ### Logistic regression
#
# Remember to set the seed.

# %%
# train the model
log_model = LogisticRegression(random_state=0,class_weight={0:0.2,1:0.80}) # remember to set the random_state / seed
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)
y_pred_prob = log_model.predict_proba(X_test)[:,1]
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    212402
#            1       0.53      0.39      0.45      1561
#
#     accuracy                           0.99    213963
#    macro avg       0.76      0.69      0.72    213963
# weighted avg       0.99      0.99      0.99    213963

# %% [markdown]
# Usually for imbalanced datasets we don't choose accuracy as the evaluation metric as it's value would be always high. So we need to lookup for other metrics like Precision, Recall, F1-score, AUC etc.
#
# First we need to understand the business to understand which among False Positive, False negative is more costly.
#
# For the True Positive, the model predicts it’s a fraud given it is really a fraud, we lock the user correctly, the company will have no costs or just administration fees.
#
# For the True Negative, the model predicts it’s a non fradulent user given he/she is really good user, we will approve it and no costs occur.
#
# For the False Positive, the model predicts as fraud user given he/she is good user, we will need to pay for the customer service fee( and potential we might loose a customer).
#
# For the False Negative, the model predicts as good user given he/she is a fraud, we approve the order wrongly and need to pay for the chargebacks while losing the amount of the order.
#
# Assuming we do have limited human resources for checking fradulent transactions, precision would be more important for us than the recall. Hence we can plot the precision-recall curve to decide upon the best threshold.

# %%
def plot_precision_recall_curve(y_test,y_prob):
    precision, recall, thresholds = precision_recall_curve(y_test, y_prob) 
    pr_auc = metrics.auc(recall, precision)
    plt.title("Precision-Recall vs Threshold Chart")
    plt.plot(thresholds, precision[: -1], "b--", label="Precision")
    plt.plot(thresholds, recall[: -1], "r--", label="Recall")
    plt.ylabel("Precision, Recall")
    plt.xlabel("Threshold")
    plt.legend(loc="lower left")
    plt.ylim([0,1])

# %%
plot_precision_recall_curve(y_test,y_pred_prob)

# %% [markdown]
# ### Random Forest

# %%
# training the model
rf_model = RandomForestClassifier(n_estimators=125,random_state=0)
rf_model.fit(X_train, y_train)
y_pred_prob_rf = rf_model.predict_proba(X_test)[:,1]

# %%
#y_pred = rf_model.predict(X_test)

# %%
plot_precision_recall_curve(y_test,y_pred_prob_rf)

# %% [markdown]
# Ideally we want high precision and recall.For this model we got the trade off at threshold 0.25 with both precison and recall as 0.5. However as per my assumption I need a better precsion than recall, I am choosing the threshold as 0.7, where precision is ~0.8 and recall is ~0.3 .
#
#
# Let's evaluate the performance of this strategy. As it is given in the task that performance should be at user level, let's join the training set with prediction to group the prediction output based upon the user.

# %%
def calc_usr_lvl_metrics(data,prob_y,threshold):
    pred_y = (prob_y >= threshold).astype(int)
    data['pred']=pred_y
    temp_df = pd.DataFrame(data.groupby(['user_id','is_fraud'])['pred'].max())
    temp_df.reset_index(inplace=True)
    print(classification_report(temp_df['is_fraud'],temp_df['pred']))

# %%
calc_usr_lvl_metrics(test,y_pred_prob_rf,0.7)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39899
#            1       0.55      0.50      0.53       151
#
#     accuracy                           1.00     40050
#    macro avg       0.77      0.75      0.76     40050
# weighted avg       1.00      1.00      1.00     40050

# %% [markdown]
# At user level, this threshold is not having high precision. Hence I increased the threshold to 0.85

# %%
calc_usr_lvl_metrics(test,y_pred_prob_rf,0.85)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     39899
#            1       0.66      0.42      0.51       151
#
#     accuracy                           1.00     40050
#    macro avg       0.83      0.71      0.76     40050
# weighted avg       1.00      1.00      1.00     40050

# %% [markdown]
# Finally, we end up getting a precision 0.66 and recall of 0.42 for the assumed strategy. However, this can further tuned to improve the performance.

# %%
# Finally let's look at the feature importance

importance = pd.Series(np.abs(rf_model.feature_importances_))
importance.index = features
importance.sort_values(inplace=True, ascending=False)
importance.plot.bar(figsize=(18,6))
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %% [markdown]
# We can see from the above plot that the newly created features like 'avg_transaction_count','transaction_hr' and 'age' variables have a significant importance in the model.

# %% [markdown]
# Finally, I have choosen the Random forest for building the models as it's performance is better than Logistic regression model . We can also try out other algorithms to find out the best algorithm.
#
# We can also perform hyper parameter tuning using Random search or grid search to increase the performance of this model.

# %%
# we persist the model for future use
joblib.dump(rf_model, '../artifacts/random_forest.pkl')
# Out:
# ['../artifacts/random_forest.pkl']

# %% [markdown]
# ### References
#
# https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc
#
# https://stats.stackexchange.com/questions/384833/adjusting-probability-threshold-for-sklearns-logistic-regression-model
#
# https://github.com/trainindata/deploying-machine-learning-models
#
# https://medium.com/datadriveninvestor/rethinking-the-right-metrics-for-fraud-detection-4edfb629c423
